# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Activation, Flatten, Conv2D, MaxPooling2D
import pickle
import os
import matplotlib.pyplot as plt

# %%
new_model = tf.keras.models.load_model('BEST.model')

# %%
pickle_in = open("X_test.pickle","rb")
X_test = pickle.load(pickle_in)

pickle_in = open("y_test.pickle","rb")
y_test = pickle.load(pickle_in)

X_test = X_test/255.0

# %%
print(X_test[:20].shape)
# Out:
# (20, 100, 100, 3)

# %%
plt.imshow(X_test[5])

# %%
predictions = new_model.predict([X_test[:20]])

# %%
print(predictions)
# Out:
# [[6.2608451e-01 2.9739525e-02 3.2944316e-01 1.4732799e-02]
#  [4.3013406e-01 5.4254746e-01 1.3609143e-02 1.3709318e-02]
#  [1.9145045e-02 1.9107459e-02 7.9760182e-01 1.6414562e-01]
#  [3.3883689e-04 5.7572750e-05 2.7501667e-01 7.2458690e-01]
#  [9.1837239e-01 3.8535410e-04 6.6129584e-03 7.4629307e-02]
#  [2.4972300e-04 2.0705567e-04 3.1130306e-02 9.6841282e-01]
#  [9.3330687e-01 3.6358640e-02 1.8858276e-02 1.1476246e-02]
#  [1.0417406e-01 6.7956895e-01 2.1363999e-01 2.6169873e-03]
#  [3.3224949e-01 4.0044400e-01 2.3433319e-01 3.2973345e-02]
#  [8.7371367e-01 7.8652941e-02 2.1864161e-02 2.5769288e-02]
#  [9.3584651e-01 4.1910790e-02 1.8147875e-02 4.0948079e-03]
#  [3.4170374e-01 6.1513197e-01 2.9180262e-02 1.3983925e-02]
#  [1.7157093e-01 1.3341743e-02 7.6424211e-01 5.0845236e-02]
#  [3.6686718e-01 1.7255555e-01 3.7766039e-01 8.2916863e-02]
#  [2.3471603e-02 2.3388169e-03 6.2278223e-01 3.5140735e-01]
#  [2.2349684e-03 1.9357198e-05 9.5920593e-01 3.8539771e-02]
# ...

# %%
import numpy as np
for i in range(20):
    print(i," ", end="")
    print(np.argmax(predictions[i]))
# Out:
# 0  0
# 1  1
# 2  2
# 3  3
# 4  0
# 5  3
# 6  0
# 7  1
# 8  1
# 9  0
# 10  0
# 11  1
# 12  2
# 13  2
# 14  2
# 15  2
# 16  1
# 17  0
# 18  2
# 19  3

# %%
plt.imshow(X_test[7])

# %%
import numpy as np

p = []

for i in predictions:
    p.append(np.argmax(predictions[i]))
        
print(p)
print([i for i in range(10)])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-745c92796fc8> in <module>
#       4
#       5 for i in predictions:
# ----> 6     p.append(np.argmax(predictions[i]))
#       7
#       8 print(p)
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
plt.imshow(X_test[17])

# %%
print("PREDCITED: ", end="")
print(p)

print("ACTUAL:    ", end="")
print("[", end="")
for i in range(20):
    print(y_test[i], end="  ")
print("]", end="")

# %%
val_loss, val_acc = new_model.evaluate(X_test, y_test)
print(val_loss)
print(val_acc)
# Out:
# 442/1 [===============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
